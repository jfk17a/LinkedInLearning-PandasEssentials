# %% [markdown]
# # Basic Plotting

# %% [markdown]
# ## Import Pandas & Matplotlib

# %%
import pandas as pd

# %%
oo = pd.read_csv('../data/olympics.csv', skiprows=4)
oo.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Plot Types

# %% [markdown]
# ### What were the different sports in the first olympics? Plot them using different graphs

# %%
fo = oo[oo.Edition == 1896]
fo.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
fo.Sport.value_counts().plot(kind='line')
# Out:
# <Axes: xlabel='Sport'>

# %%
fo.Sport.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Sport'>

# %%
fo.Sport.value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='Sport'>

# %%
fo.Sport.value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ## Plot Colors

# %%
fo.Sport.value_counts().plot(color='plum')
# Out:
# <Axes: xlabel='Sport'>

# %%
fo.Sport.value_counts().plot(kind='bar',color='maroon')
# Out:
# <Axes: xlabel='Sport'>

# %% [markdown]
# ## Figure Size

# %%
fo.Sport.value_counts().plot(figsize=(10,3))
# Out:
# <Axes: xlabel='Sport'>

# %% [markdown]
# ## Colormaps

# %%
fo.Sport.value_counts().plot(kind='pie',colormap='Pastel1')
# Out:
# <Axes: ylabel='count'>

# %%
fo.Sport.value_counts().plot(kind='pie',colormap='red')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 fo.Sport.value_counts().plot(kind='pie',colormap='red')
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\plotting\_core.py:975, in PlotAccessor.__call__(self, *args, **kwargs)
#     972             label_name = label_kw or data.columns
#     973             data.columns = label_name
# --> 975 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\core.py:448, in MPLPlot.generate(self)
#     446 self._compute_plot_data()
#     447 self._setup_subplots()
# --> 448 self._make_plot()
#     449 self._add_table()
#     450 self._make_legend()
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\core.py:1833, in PiePlot._make_plot(self)
#    1832 def _make_plot(self) -> None:
# -> 1833     colors = self._get_colors(num_colors=len(self.data), color_kwds="colors")
#    1834     self.kwds.setdefault("colors", colors)
#    1836     for i, (label, y) in enumerate(self._iter_data()):
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\core.py:995, in MPLPlot._get_colors(self, num_colors, color_kwds)
#     992 if num_colors is None:
#     993     num_colors = self.nseries
# --> 995 return get_standard_colors(
#     996     num_colors=num_colors,
#     997     colormap=self.colormap,
#     998     color=self.kwds.get(color_kwds),
#     999 )
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\style.py:68, in get_standard_colors(num_colors, colormap, color_type, color)
#      65 if isinstance(color, dict):
#      66     return color
# ---> 68 colors = _derive_colors(
#      69     color=color,
#      70     colormap=colormap,
#      71     color_type=color_type,
#      72     num_colors=num_colors,
#      73 )
#      75 return list(_cycle_colors(colors, num_colors=num_colors))
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\style.py:118, in _derive_colors(color, colormap, color_type, num_colors)
#      85 """
#      86 Derive colors from either `colormap`, `color_type` or `color` inputs.
#      87
#    (...)
#     115     Parameter `color` will override.
#     116 """
#     117 if color is None and colormap is not None:
# --> 118     return _get_colors_from_colormap(colormap, num_colors=num_colors)
#     119 elif color is not None:
#     120     if colormap is not None:
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\style.py:145, in _get_colors_from_colormap(colormap, num_colors)
#     140 def _get_colors_from_colormap(
#     141     colormap: str | Colormap,
#     142     num_colors: int,
#     143 ) -> list[Color]:
#     144     """Get colors from colormap."""
# --> 145     cmap = _get_cmap_instance(colormap)
#     146     return [cmap(num) for num in np.linspace(0, 1, num=num_colors)]
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\plotting\_matplotlib\style.py:153, in _get_cmap_instance(colormap)
#     151 if isinstance(colormap, str):
#     152     cmap = colormap
# --> 153     colormap = mpl.colormaps[colormap]
#     154     if colormap is None:
#     155         raise ValueError(f"Colormap {cmap} is not recognized")
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\matplotlib\cm.py:82, in ColormapRegistry.__getitem__(self, item)
#      80     return self._cmaps[item].copy()
#      81 except KeyError:
# ---> 82     raise KeyError(f"{item!r} is not a known colormap name") from None
#
# KeyError: "'red' is not a known colormap name"

# %% [markdown]
# ## Seaborn Basic Plotting

# %%
import seaborn as sns

# %% [markdown]
# ## How many medals have been won by men and women in the history of the Olympics. How many gold, silver, and bronze medals were won for each gender?

# %%
sns.countplot(x='Medal',data=oo, hue='Gender')
# Out:
# <Axes: xlabel='Medal', ylabel='count'>
